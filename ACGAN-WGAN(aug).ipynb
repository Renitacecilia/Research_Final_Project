# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Reshape, Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, Activation, Input, Lambda, GlobalAveragePooling2D, Concatenate, PReLU, LeakyReLU, Embedding, multiply
from tensorflow.keras.activations import relu, softmax
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.utils import to_categorical, load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, CSVLogger
import os
from os import listdir
from tqdm import tqdm
import shutil
import cv2
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model
import time
import itertools
from sklearn.utils import resample  # Import resample
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Print TensorFlow and Keras versions
print(tf.__version__)
print(tf.keras.__version__)

# Check GPU status
os.system('nvidia-smi')

# Callbacks
epochs = 50

earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=epochs,
                          verbose=1,
                          restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=5,
                              verbose=1,
                              min_delta=0.0001)

csv_logger = CSVLogger('Model.log')

callbacks = [earlystop, csv_logger, reduce_lr]

# Intersection over Union (IoU)
def iou(y_true, y_pred, smooth=0.5):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# Computing Sensitivity
def sensitivity(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# Computing Specificity
def specificity(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def f1_score(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

# Define Dice coefficient metric
def dice_coefficient(y_true, y_pred, epsilon=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_flat = tf.reshape(y_true, [-1])
    y_pred_flat = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_flat * y_pred_flat)
    dice_score = (2.0 * intersection + epsilon) / (tf.reduce_sum(y_true_flat) + tf.reduce_sum(y_pred_flat) + epsilon)
    return dice_score

def tversky(y_true, y_pred, smooth=1, alpha=0.7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1 - y_pred_pos))
    false_pos = K.sum((1 - y_true_pos) * y_pred_pos)
    return (true_pos + smooth) / (true_pos + alpha * false_neg + (1 - alpha) * false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)

def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    tv = tversky(y_true, y_pred)
    return K.pow((1 - tv), gamma)

def confusion_matrix_img(y_pred, y_true, savename):
    cm = confusion_matrix(y_true, y_pred)
    labels = ['benign', 'malignant']
    title='Confusion matrix'
    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.savefig(savename)
    plt.show()

# Create directories for augmented data
size = 128
os.makedirs('augmented/benign', exist_ok=True)
os.makedirs('augmented/malignant', exist_ok=True)

def getListOfFiles(dirName):
    listOfFile = os.listdir(dirName)
    allFiles = list()
    for entry in listOfFile:
        fullPath = os.path.join(dirName, entry)
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
    return allFiles

# Copy benign images to the augmented directory
files_benign = getListOfFiles('/Users/renitalewis/Downloads/archive/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign')
for f in files_benign:
    if f.endswith('.png'):
        shutil.copy(f, 'augmented/benign')

# Copy malignant images to the augmented directory
files_malignant = getListOfFiles('/Users/renitalewis/Downloads/archive/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/malignant')
for f in files_malignant:
    if f.endswith('.png'):
        shutil.copy(f, 'augmented/malignant')

benign_images = getListOfFiles('augmented/benign')
malignent_images = getListOfFiles('augmented/malignant')

# Load and display an image
image_path = benign_images[9]
img = load_img(image_path, target_size=(size, size), color_mode='rgb')
img_array = img_to_array(img)
plt.imshow(img_array.astype('uint8'))
plt.axis('off')
plt.show()

# Load and display another image
image_path = malignent_images[45]
img = load_img(image_path, target_size=(size, size), color_mode='rgb')
img_array = img_to_array(img)
plt.imshow(img_array.astype('uint8'))
plt.axis('off')
plt.show()

# Prepare the DataFrame
total_images = len(benign_images) + len(malignent_images)
data = pd.DataFrame(index=np.arange(0, total_images), columns=["image", "target"])

k = 0
for c, image_list in enumerate([benign_images, malignent_images]):
    for image_path in image_list:
        data.loc[k, "image"] = image_path
        data.loc[k, "target"] = c
        k += 1

print(data.shape)
print(data.head())

count_data = data["target"].value_counts()
ben_upsampled = resample(data[data['target']==0], n_samples=data[data['target']==1].shape[0], random_state=42)
up_sampled = pd.concat([data[data['target']==1], ben_upsampled])
up_sampled['target'].value_counts()

# Corrected loop to load images
train_image = []
y = []

for i in tqdm(range(up_sampled.shape[0])):
    img = tf.keras.utils.load_img(up_sampled['image'].iloc[i], target_size=(size, size), color_mode='rgb')
    img = tf.keras.utils.img_to_array(img)
    img = img / 255.0
    train_image.append(img)
        
X = np.array(train_image)
y = up_sampled.iloc[:, -1].values

# KFold split
kf = KFold(n_splits=10, random_state=42, shuffle=True)

for train_index, test_index in kf.split(X, y):
    X_train, X_test, y_train, y_test = X[train_index], X[test_index], y[train_index], y[test_index]

for train_index, test_index in kf.split(X_test, y_test):
    X2_test, X_val, y2_test, y_val = X_test[train_index], X_test[test_index], y_test[train_index], y_test[test_index]

Y_train = to_categorical(y_train, 2)
Y_test = to_categorical(y2_test, 2)
Y_val = to_categorical(y_val, 2)

print(X_train.shape)
print(X2_test.shape)
print(X_val.shape)

data_gen = ImageDataGenerator(
    zoom_range=1.2,  # set range for random zoom
    rotation_range=90,
    width_shift_range=0.5,
    height_shift_range=0.5,
    horizontal_flip=True,  # randomly flip images
    vertical_flip=True,  # randomly flip images
)

data_gen.fit(X_train)
data_gen.fit(X_val)
data_gen.fit(X2_test)

# WGAN-GP Loss functions
def wasserstein_loss(y_true, y_pred):
    return K.mean(y_true * y_pred)

def gradient_penalty_loss(y_true, y_pred, averaged_samples, lambda_gp):
    gradients = K.gradients(y_pred, averaged_samples)[0]
    gradients_sqr = K.square(gradients)
    gradient_penalty = K.sum(gradients_sqr, axis=np.arange(1, len(gradients_sqr.shape)))
    return K.mean((gradient_penalty - 1.0) ** 2) * lambda_gp

# ACGAN-WGAN-GP Architecture
def build_generator(noise_dim, num_classes, img_shape):
    noise = Input(shape=(noise_dim,))
    label = Input(shape=(1,), dtype='int32')
    
    label_embedding = Flatten()(Embedding(num_classes, noise_dim)(label))
    model_input = multiply([noise, label_embedding])
    
    x = Dense(256)(model_input)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Dense(512)(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Dense(1024)(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Dense(np.prod(img_shape), activation='tanh')(x)
    img = Reshape(img_shape)(x)
    
    return Model([noise, label], img)

def build_discriminator(img_shape, num_classes):
    img = Input(shape=img_shape)
    
    x = Flatten()(img)
    x = Dense(512)(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = Dense(256)(x)
    x = LeakyReLU(alpha=0.2)(x)
    
    validity = Dense(1, name='validity')(x)
    label = Dense(num_classes, activation='softmax', name='label')(x)
    
    return Model(img, [validity, label])

# Set image shape and noise dimension
img_shape = (size, size, 3)
noise_dim = 100
num_classes = 2
lambda_gp = 10  # Gradient penalty lambda hyperparameter

# Build and compile the discriminator
discriminator = build_discriminator(img_shape, num_classes)
discriminator.compile(loss={'validity': wasserstein_loss, 'label': 'sparse_categorical_crossentropy'},
                      optimizer=Adam(0.0002, 0.5),
                      metrics={'label': 'accuracy'})  # Updated metrics

# Build the generator
generator = build_generator(noise_dim, num_classes, img_shape)

# The generator takes noise and label as input and generates images
noise = Input(shape=(noise_dim,))
label = Input(shape=(1,))
img = generator([noise, label])

# For the combined model, we only train the generator
discriminator.trainable = False

# The discriminator takes generated images as input and determines validity and class label
validity, target_label = discriminator(img)

# The combined model (stacked generator and discriminator)
gan = Model([noise, label], [validity, target_label])
gan.compile(loss=[wasserstein_loss, 'sparse_categorical_crossentropy'],
            optimizer=Adam(0.0002, 0.5))

# Training the ACGAN-WGAN-GP
def train_acgan_wgan_gp(epochs, batch_size, save_interval):
    X_train_wgan = X_train * 2 - 1  # Normalize to [-1, 1] for tanh activation
    valid = -np.ones((batch_size, 1), dtype=np.float32)
    fake = np.ones((batch_size, 1), dtype=np.float32)
    
    for epoch in range(epochs):
        for _ in range(5):
            idx = np.random.randint(0, X_train_wgan.shape[0], batch_size)
            imgs, labels = X_train_wgan[idx], y_train[idx]
            
            noise = np.random.normal(0, 1, (batch_size, noise_dim))
            gen_labels = np.random.randint(0, num_classes, batch_size)
            gen_imgs = generator.predict([noise, gen_labels])
            
            d_loss_real = discriminator.train_on_batch(imgs, [valid, labels.astype(np.float32)])
            d_loss_fake = discriminator.train_on_batch(gen_imgs, [fake, gen_labels.astype(np.float32)])
            d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
            
            noise = np.random.normal(0, 1, (batch_size, noise_dim))
            sampled_labels = np.random.randint(0, num_classes, batch_size)
            valid = -np.ones((batch_size, 1), dtype=np.float32)
            
            g_loss = gan.train_on_batch([noise, sampled_labels], [valid, sampled_labels.astype(np.float32)])
        
        print(f"{epoch} [D loss: {d_loss[0]} | D accuracy: {100 * d_loss[1]}] [G loss: {g_loss[0]}]")
        
        if epoch % save_interval == 0:
            save_imgs(epoch)

def save_imgs(epoch):
    r, c = 5, 5
    noise = np.random.normal(0, 1, (r * c, noise_dim))
    sampled_labels = np.random.randint(0, num_classes, r * c)
    gen_imgs = generator.predict([noise, sampled_labels])
    
    gen_imgs = 0.5 * gen_imgs + 0.5
    
    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i, j].imshow(gen_imgs[cnt, :, :, :])
            axs[i, j].axis('off')
            cnt += 1
    fig.savefig("images/acgan_wgan_%d.png" % epoch)
    plt.close()

# Train the ACGAN-WGAN-GP for a specified number of epochs
train_acgan_wgan_gp(epochs=50, batch_size=16, save_interval=200)  # Reduced batch size to 16

# Generate new images using the trained generator
def generate_images(generator, num_images, noise_dim, num_classes):
    noise = np.random.normal(0, 1, (num_images, noise_dim))
    sampled_labels = np.random.randint(0, num_classes, num_images)
    gen_imgs = generator.predict([noise, sampled_labels])
    gen_imgs = 0.5 * gen_imgs + 0.5  # Rescale to [0, 1]
    return gen_imgs

# Generate a set of synthetic images
num_synthetic_images = 1000
synthetic_images = generate_images(generator, num_synthetic_images, noise_dim, num_classes)

# Add these synthetic images to your training set
X_train_augmented = np.concatenate((X_train, synthetic_images))
y_train_augmented = np.concatenate((y_train, np.full((num_synthetic_images,), 1)))  # Assuming class 1 for synthetic images

# Proceed with the rest of your training as usual
Y_train_augmented = to_categorical(y_train_augmented, 2)

strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

# Model architecture
def bottleneck0(inputs):
    backbone = tf.keras.applications.EfficientNetV2B0(weights='imagenet', include_top=False)
    x = backbone(inputs)
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)  # Bottleneck layer with EfficientNet
    x = Flatten()(x)
    return x

def neck_section(inputs):
    x = Conv2D(256, (7, 7), strides=(2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = PReLU()(x)  # Use PReLU directly as a layer
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = Flatten()(x)
    return x

def vision_transform(inputs, patch_size):
    x = Reshape((patch_size[0], patch_size[1], -1))(inputs)
    x = Lambda(lambda image: tf.cast(image, 'float32') / 255.0)(x)
    x = Conv2D(64, (3, 3), activation='relu')(x)
    x = Conv2D(64, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu')(x)
    x = Conv2D(128, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    return x

def create_model(input_shape, num_classes, patch_size):
    inputs = Input(shape=input_shape)
    efficientnet_bottleneck = bottleneck0(inputs)
    patches_transform = vision_transform(inputs, patch_size)
    neck = neck_section(inputs)
    merged = Concatenate()([efficientnet_bottleneck, patches_transform, neck])
    outputs = Dense(num_classes, activation='softmax')(merged)
    model = Model(inputs=inputs, outputs=outputs)
    return model

input_shape = (size, size, 3)
num_classes = 2
patch_size = (32, 32)
batch_size = 16  # Reduced batch size to 16

with strategy.scope():
    model = create_model(input_shape, num_classes, patch_size)
    model.compile(loss="categorical_crossentropy",
                  optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07),
                  metrics=['accuracy', tf.keras.metrics.Precision(name='precision'),
                           tf.keras.metrics.Recall(name='recall'),
                           tf.keras.metrics.AUC(name='AUC'),
                           f1_score, specificity, sensitivity, iou, tversky])

print(model.input_shape)
print(model.output_shape)
model.summary()

# Measure the training time using the time module
start_time = time.time()
history = model.fit(data_gen.flow(X_train_augmented, Y_train_augmented,
                                       batch_size=batch_size, 
                                       seed=27,
                                       shuffle=True),
                    callbacks=callbacks,
                    epochs=50,
                    steps_per_epoch=X_train_augmented.shape[0] // batch_size,
                    validation_data=data_gen.flow(X_val, Y_val,
                                       batch_size=batch_size, 
                                       seed=27,
                                       shuffle=True))
end_time = time.time()

print("Training time: {:.2f} seconds".format(end_time - start_time))
model.save("modelBH.h5")
print("Saved model to disk")

df = pd.DataFrame(history.history) 
df.to_excel("output.xlsx")
df.head(50)

# Interpreting the Metrics
fig, ax = plt.subplots(5, 2, figsize=(15, 30))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss', 'precision', 'recall', 'AUC', 'f1_score', 'sensitivity', 'specificity', 'iou', 'tversky']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
plt.savefig("Model-Results.png")

Test_data = (data_gen.flow(X2_test, Y_test,
                          batch_size=32,  # Reduced batch size to 32
                          seed=27,
                          shuffle=True))

# Evaluate the model on the test data
print("Evaluate on test data")
results = model.evaluate(Test_data, batch_size=16, callbacks=callbacks)  # Reduced batch size to 16
print("test loss test acc:", results)

truey = []
predy = []
x = X2_test
y = Y_test

yhat = model.predict(x)
yh = yhat.tolist()
yt = y.tolist()
count = 0

for i in range(len(y)):
    yy = max(yh[i])
    yyt = max(yt[i])
    predy.append(yh[i].index(yy))
    truey.append(yt[i].index(yyt))
    if(yh[i].index(yy) == yt[i].index(yyt)):
        count += 1

acc = (count / len(y)) * 100

# Saving values for confusion matrix and analysis
np.save('truey', truey)
np.save('predy', predy)
print("Predicted and true label values saved")
print("Accuracy on test set :" + str(acc) + "%")

# Plot confusion matrix
confusion_matrix_img(truey, predy, savename='Confusion Matrix')
# Out:
# 2.16.2
# 3.4.1
# sh: nvidia-smi: command not found
# (7909, 2)
#                                              image target
# 0  augmented/benign/SOB_B_F-14-23060CD-100-001.png      0
# 1  augmented/benign/SOB_B_TA-14-19854C-200-016.png      0
# 2  augmented/benign/SOB_B_TA-14-19854C-200-002.png      0
# 3    augmented/benign/SOB_B_F-14-25197-400-039.png      0
# 4   augmented/benign/SOB_B_F-14-14134E-100-007.png      0
# 100%|████████████████████████████████████| 10858/10858 [01:04<00:00, 167.21it/s]
# (9773, 128, 128, 3)
# (977, 128, 128, 3)
# (108, 128, 128, 3)
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x28e3ca520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x28e41c540> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 0 [D loss: 0.24347904324531555 | D accuracy: 54.93055582046509] [G loss: 0.29264378547668457]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1 [D loss: 0.5439920425415039 | D accuracy: 53.059208393096924] [G loss: 0.6078521609306335]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2 [D loss: 0.9771732091903687 | D accuracy: 50.53160786628723] [G loss: 1.0435292720794678]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 3 [D loss: 1.7412803173065186 | D accuracy: 49.13060665130615] [G loss: 1.850817322731018]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4 [D loss: 3.1087775230407715 | D accuracy: 50.81760287284851] [G loss: 3.3302056789398193]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 5 [D loss: 5.701500415802002 | D accuracy: 51.050496101379395] [G loss: 6.051549911499023]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 6 [D loss: 9.065932273864746 | D accuracy: 52.29361057281494] [G loss: 9.549137115478516]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 7 [D loss: 12.580333709716797 | D accuracy: 53.144776821136475] [G loss: 13.04560375213623]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 8 [D loss: 15.669193267822266 | D accuracy: 53.561562299728394] [G loss: 16.014768600463867]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 9 [D loss: 18.49776268005371 | D accuracy: 53.89394164085388] [G loss: 18.789064407348633]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10 [D loss: 20.709453582763672 | D accuracy: 54.3093204498291] [G loss: 21.029451370239258]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11 [D loss: 23.05788230895996 | D accuracy: 54.07956838607788] [G loss: 23.364408493041992]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 12 [D loss: 25.15433120727539 | D accuracy: 54.005664587020874] [G loss: 25.44399070739746]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 13 [D loss: 26.999488830566406 | D accuracy: 54.390257596969604] [G loss: 27.261281967163086]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 14 [D loss: 28.598529815673828 | D accuracy: 54.95399832725525] [G loss: 28.867206573486328]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 15 [D loss: 30.13397979736328 | D accuracy: 55.27012348175049] [G loss: 30.363056182861328]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 16 [D loss: 31.559833526611328 | D accuracy: 55.01457452774048] [G loss: 31.752357482910156]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 17 [D loss: 32.939720153808594 | D accuracy: 55.083608627319336] [G loss: 33.182273864746094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 18 [D loss: 34.33409118652344 | D accuracy: 55.19458055496216] [G loss: 34.555179595947266]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 19 [D loss: 35.624420166015625 | D accuracy: 55.451083183288574] [G loss: 35.85810852050781]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 20 [D loss: 36.847007751464844 | D accuracy: 55.4445743560791] [G loss: 37.068851470947266]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 21 [D loss: 37.938331604003906 | D accuracy: 54.869043827056885] [G loss: 38.12405014038086]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 22 [D loss: 39.002662658691406 | D accuracy: 55.11984825134277] [G loss: 39.18243408203125]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 23 [D loss: 39.99609375 | D accuracy: 55.38877248764038] [G loss: 40.173404693603516]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 24 [D loss: 41.05550765991211 | D accuracy: 55.21044135093689] [G loss: 41.23948287963867]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 25 [D loss: 42.117591857910156 | D accuracy: 55.19016981124878] [G loss: 42.309814453125]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 26 [D loss: 43.14863586425781 | D accuracy: 55.136775970458984] [G loss: 43.30165481567383]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 27 [D loss: 44.10144805908203 | D accuracy: 54.99783754348755] [G loss: 44.260799407958984]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 28 [D loss: 44.879051208496094 | D accuracy: 54.98709678649902] [G loss: 45.04035186767578]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 29 [D loss: 45.840721130371094 | D accuracy: 54.789263010025024] [G loss: 46.01171112060547]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 30 [D loss: 46.77402877807617 | D accuracy: 54.81623411178589] [G loss: 46.94331359863281]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 31 [D loss: 47.52410888671875 | D accuracy: 54.733967781066895] [G loss: 47.68364715576172]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 32 [D loss: 48.28838348388672 | D accuracy: 54.75153923034668] [G loss: 48.44310760498047]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 33 [D loss: 49.00767517089844 | D accuracy: 54.62077856063843] [G loss: 49.15107345581055]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 34 [D loss: 49.644859313964844 | D accuracy: 54.74782586097717] [G loss: 49.7646369934082]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 35 [D loss: 50.13197326660156 | D accuracy: 54.711365699768066] [G loss: 50.25741195678711]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 36 [D loss: 50.84384536743164 | D accuracy: 54.88830208778381] [G loss: 50.992279052734375]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 37 [D loss: 51.44800567626953 | D accuracy: 54.981863498687744] [G loss: 51.56324005126953]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 38 [D loss: 52.048789978027344 | D accuracy: 55.03050088882446] [G loss: 52.171478271484375]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 39 [D loss: 52.56251907348633 | D accuracy: 55.162692070007324] [G loss: 52.702293395996094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 40 [D loss: 53.200157165527344 | D accuracy: 55.250293016433716] [G loss: 53.319271087646484]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 41 [D loss: 53.9352912902832 | D accuracy: 55.21453022956848] [G loss: 54.07001495361328]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 42 [D loss: 54.39363098144531 | D accuracy: 55.22410869598389] [G loss: 54.471885681152344]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 43 [D loss: 54.86769104003906 | D accuracy: 55.22608757019043] [G loss: 54.973243713378906]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 44 [D loss: 55.29833221435547 | D accuracy: 55.1932692527771] [G loss: 55.3958740234375]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 45 [D loss: 55.63676452636719 | D accuracy: 55.22988438606262] [G loss: 55.74754333496094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 46 [D loss: 56.10071563720703 | D accuracy: 55.19169569015503] [G loss: 56.20061492919922]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47 [D loss: 56.400474548339844 | D accuracy: 55.246323347091675] [G loss: 56.49895477294922]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 48 [D loss: 56.88835906982422 | D accuracy: 55.20302057266235] [G loss: 57.01154327392578]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 49 [D loss: 57.37224197387695 | D accuracy: 55.24275302886963] [G loss: 57.496421813964844]
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# Number of devices: 1
# (None, 128, 128, 3)
# (None, 2)
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 32, 32,    │          0 │ input_layer_5[0]… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 32, 32,    │          0 │ reshape_1[0][0]   │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 30, 30,    │     27,712 │ lambda[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 28, 28,    │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ efficientnetv2-b0   │ (None, 4, 4,      │  5,919,312 │ input_layer_5[0]… │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 14, 14,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     37,888 │ input_layer_5[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ efficientnetv2-b… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 12, 12,    │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1280)      │      5,120 │ global_average_p… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 10, 10,    │    147,584 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu (PReLU)     │ (None, 64, 64,    │  1,048,576 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │    327,936 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 5, 5, 128) │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ p_re_lu[0][0]     │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 256)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 3200)      │          0 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_4 (Flatten) │ (None, 262144)    │          0 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 265600)    │          0 │ flatten_2[0][0],  │
# │ (Concatenate)       │                   │            │ flatten_3[0][0],  │
# │                     │                   │            │ flatten_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 2)         │    531,202 │ concatenate[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,157,138 (31.12 MB)
#  Trainable params: 8,093,458 (30.87 MB)
#  Non-trainable params: 63,680 (248.75 KB)
# Epoch 1/50
# 2024-07-21 13:59:55.400002: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - AUC: 0.6826 - accuracy: 0.6668 - f1_score: 0.6667 - iou: 0.5290 - loss: 13.9397 - precision: 0.6668 - recall: 0.6668 - sensitivity: 0.6667 - specificity: 0.6667 - tversky: 0.6890
# 2024-07-21 14:04:35.255089: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 281s 398ms/step - AUC: 0.6826 - accuracy: 0.6668 - f1_score: 0.6668 - iou: 0.5290 - loss: 13.9350 - precision: 0.6668 - recall: 0.6668 - sensitivity: 0.6668 - specificity: 0.6668 - tversky: 0.6890 - val_AUC: 0.5370 - val_accuracy: 0.5370 - val_f1_score: 0.5446 - val_iou: 0.4045 - val_loss: 113.0271 - val_precision: 0.5370 - val_recall: 0.5370 - val_sensitivity: 0.5446 - val_specificity: 0.5446 - val_tversky: 0.5721 - learning_rate: 0.0010
# Epoch 2/50
# 2024-07-21 14:04:36.703383: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 14:04:36.859799: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 4:58 444ms/step - AUC: 0.5664 - accuracy: 0.5625 - f1_score: 0.5625 - iou: 0.3797 - loss: 16.1589 - precision: 0.5625 - recall: 0.5625 - sensitivity: 0.5625 - specificity: 0.5625 - tversky: 0.5636
# 2024-07-21 14:04:37.303674: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# /opt/anaconda3/lib/python3.12/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.5664 - accuracy: 0.5625 - f1_score: 0.2817 - iou: 0.1901 - loss: 16.1589 - precision: 0.5625 - recall: 0.5625 - sensitivity: 0.2817 - specificity: 0.2817 - tversky: 0.2822 - val_AUC: 0.5370 - val_accuracy: 0.5370 - val_f1_score: 0.5357 - val_iou: 0.3869 - val_loss: 95.4709 - val_precision: 0.5370 - val_recall: 0.5370 - val_sensitivity: 0.5357 - val_specificity: 0.5357 - val_tversky: 0.5643 - learning_rate: 0.0010
# Epoch 3/50
# 2024-07-21 14:04:37.947974: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - AUC: 0.7247 - accuracy: 0.7062 - f1_score: 0.7061 - iou: 0.5709 - loss: 8.0202 - precision: 0.7062 - recall: 0.7062 - sensitivity: 0.7061 - specificity: 0.7061 - tversky: 0.7228
# 2024-07-21 14:09:16.143081: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 279s 414ms/step - AUC: 0.7247 - accuracy: 0.7062 - f1_score: 0.7061 - iou: 0.5709 - loss: 8.0183 - precision: 0.7062 - recall: 0.7062 - sensitivity: 0.7061 - specificity: 0.7061 - tversky: 0.7228 - val_AUC: 0.5370 - val_accuracy: 0.5370 - val_f1_score: 0.5327 - val_iou: 0.3815 - val_loss: 34.8002 - val_precision: 0.5370 - val_recall: 0.5370 - val_sensitivity: 0.5327 - val_specificity: 0.5327 - val_tversky: 0.5617 - learning_rate: 0.0010
# Epoch 4/50
# 2024-07-21 14:09:16.837040: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 14:09:16.966886: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 5:14 467ms/step - AUC: 0.8477 - accuracy: 0.8125 - f1_score: 0.8125 - iou: 0.6908 - loss: 1.8952 - precision: 0.8125 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.8125 - tversky: 0.8225
# 2024-07-21 14:09:17.435601: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.8477 - accuracy: 0.8125 - f1_score: 0.4069 - iou: 0.3459 - loss: 1.8952 - precision: 0.8125 - recall: 0.8125 - sensitivity: 0.4069 - specificity: 0.4069 - tversky: 0.4119 - val_AUC: 0.5370 - val_accuracy: 0.5370 - val_f1_score: 0.5417 - val_iou: 0.3973 - val_loss: 34.3020 - val_precision: 0.5370 - val_recall: 0.5370 - val_sensitivity: 0.5417 - val_specificity: 0.5417 - val_tversky: 0.5695 - learning_rate: 0.0010
# Epoch 5/50
# 2024-07-21 14:09:18.207713: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - AUC: 0.7617 - accuracy: 0.7233 - f1_score: 0.7232 - iou: 0.5894 - loss: 3.6537 - precision: 0.7233 - recall: 0.7233 - sensitivity: 0.7232 - specificity: 0.7232 - tversky: 0.7392
# 2024-07-21 14:14:12.216183: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 295s 437ms/step - AUC: 0.7617 - accuracy: 0.7233 - f1_score: 0.7232 - iou: 0.5894 - loss: 3.6535 - precision: 0.7233 - recall: 0.7233 - sensitivity: 0.7232 - specificity: 0.7232 - tversky: 0.7392 - val_AUC: 0.7528 - val_accuracy: 0.6944 - val_f1_score: 0.6935 - val_iou: 0.5486 - val_loss: 2.0351 - val_precision: 0.6944 - val_recall: 0.6944 - val_sensitivity: 0.6935 - val_specificity: 0.6935 - val_tversky: 0.7087 - learning_rate: 0.0010
# Epoch 6/50
# 2024-07-21 14:14:12.893049: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 14:14:13.025678: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 4:54 439ms/step - AUC: 0.8906 - accuracy: 0.8125 - f1_score: 0.8125 - iou: 0.7259 - loss: 1.0387 - precision: 0.8125 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.8125 - tversky: 0.8458
# 2024-07-21 14:14:13.465775: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.8906 - accuracy: 0.8125 - f1_score: 0.4069 - iou: 0.3635 - loss: 1.0387 - precision: 0.8125 - recall: 0.8125 - sensitivity: 0.4069 - specificity: 0.4069 - tversky: 0.4235 - val_AUC: 0.7428 - val_accuracy: 0.6759 - val_f1_score: 0.6696 - val_iou: 0.5319 - val_loss: 2.9335 - val_precision: 0.6759 - val_recall: 0.6759 - val_sensitivity: 0.6696 - val_specificity: 0.6696 - val_tversky: 0.6981 - learning_rate: 0.0010
# Epoch 7/50
# 2024-07-21 14:14:14.177775: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - AUC: 0.7779 - accuracy: 0.7264 - f1_score: 0.7264 - iou: 0.5913 - loss: 2.4160 - precision: 0.7264 - recall: 0.7264 - sensitivity: 0.7264 - specificity: 0.7264 - tversky: 0.7410
# 2024-07-21 14:19:13.493678: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 300s 445ms/step - AUC: 0.7779 - accuracy: 0.7264 - f1_score: 0.7264 - iou: 0.5913 - loss: 2.4154 - precision: 0.7264 - recall: 0.7264 - sensitivity: 0.7264 - specificity: 0.7264 - tversky: 0.7411 - val_AUC: 0.8026 - val_accuracy: 0.7500 - val_f1_score: 0.7470 - val_iou: 0.5983 - val_loss: 1.3920 - val_precision: 0.7500 - val_recall: 0.7500 - val_sensitivity: 0.7470 - val_specificity: 0.7470 - val_tversky: 0.7525 - learning_rate: 0.0010
# Epoch 8/50
# 2024-07-21 14:19:14.189110: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 14:19:14.321805: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 5:02 450ms/step - AUC: 0.6211 - accuracy: 0.6250 - f1_score: 0.6250 - iou: 0.4573 - loss: 3.9871 - precision: 0.6250 - recall: 0.6250 - sensitivity: 0.6250 - specificity: 0.6250 - tversky: 0.6386
# 2024-07-21 14:19:14.773532: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.6211 - accuracy: 0.6250 - f1_score: 0.3130 - iou: 0.2290 - loss: 3.9871 - precision: 0.6250 - recall: 0.6250 - sensitivity: 0.3130 - specificity: 0.3130 - tversky: 0.3198 - val_AUC: 0.8494 - val_accuracy: 0.7500 - val_f1_score: 0.7560 - val_iou: 0.6453 - val_loss: 1.0681 - val_precision: 0.7500 - val_recall: 0.7500 - val_sensitivity: 0.7560 - val_specificity: 0.7560 - val_tversky: 0.7804 - learning_rate: 0.0010
# Epoch 9/50
# 2024-07-21 14:19:15.495304: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - AUC: 0.8065 - accuracy: 0.7414 - f1_score: 0.7413 - iou: 0.6013 - loss: 1.3758 - precision: 0.7414 - recall: 0.7414 - sensitivity: 0.7413 - specificity: 0.7413 - tversky: 0.7502
# 2024-07-21 14:24:21.190165: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 306s 455ms/step - AUC: 0.8065 - accuracy: 0.7414 - f1_score: 0.7413 - iou: 0.6013 - loss: 1.3757 - precision: 0.7414 - recall: 0.7414 - sensitivity: 0.7413 - specificity: 0.7413 - tversky: 0.7502 - val_AUC: 0.8765 - val_accuracy: 0.7870 - val_f1_score: 0.7827 - val_iou: 0.6478 - val_loss: 0.7437 - val_precision: 0.7870 - val_recall: 0.7870 - val_sensitivity: 0.7827 - val_specificity: 0.7827 - val_tversky: 0.7872 - learning_rate: 0.0010
# Epoch 10/50
# 2024-07-21 14:24:21.879176: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 14:24:22.022833: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 5:01 448ms/step - AUC: 0.9297 - accuracy: 0.8750 - f1_score: 0.8750 - iou: 0.6895 - loss: 0.3434 - precision: 0.8750 - recall: 0.8750 - sensitivity: 0.8750 - specificity: 0.8750 - tversky: 0.8216
# 2024-07-21 14:24:22.472051: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.9297 - accuracy: 0.8750 - f1_score: 0.4382 - iou: 0.3453 - loss: 0.3434 - precision: 0.8750 - recall: 0.8750 - sensitivity: 0.4382 - specificity: 0.4382 - tversky: 0.4114 - val_AUC: 0.8595 - val_accuracy: 0.7778 - val_f1_score: 0.7827 - val_iou: 0.6706 - val_loss: 1.0076 - val_precision: 0.7778 - val_recall: 0.7778 - val_sensitivity: 0.7827 - val_specificity: 0.7827 - val_tversky: 0.8042 - learning_rate: 0.0010
# Epoch 11/50
# 2024-07-21 14:24:23.221728: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - AUC: 0.8331 - accuracy: 0.7551 - f1_score: 0.7551 - iou: 0.6101 - loss: 0.8992 - precision: 0.7551 - recall: 0.7551 - sensitivity: 0.7551 - specificity: 0.7551 - tversky: 0.7584
# 2024-07-21 14:29:40.928082: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 318s 473ms/step - AUC: 0.8331 - accuracy: 0.7551 - f1_score: 0.7551 - iou: 0.6101 - loss: 0.8992 - precision: 0.7551 - recall: 0.7551 - sensitivity: 0.7551 - specificity: 0.7551 - tversky: 0.7584 - val_AUC: 0.4289 - val_accuracy: 0.4352 - val_f1_score: 0.4435 - val_iou: 0.3086 - val_loss: 1.9970 - val_precision: 0.4352 - val_recall: 0.4352 - val_sensitivity: 0.4435 - val_specificity: 0.4435 - val_tversky: 0.4827 - learning_rate: 0.0010
# Epoch 12/50
# 2024-07-21 14:29:41.623898: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 14:29:41.724148: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 5:20 477ms/step - AUC: 0.4844 - accuracy: 0.4375 - f1_score: 0.4375 - iou: 0.3168 - loss: 1.8460 - precision: 0.4375 - recall: 0.4375 - sensitivity: 0.4375 - specificity: 0.4375 - tversky: 0.4964
# 2024-07-21 14:29:42.202884: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.4844 - accuracy: 0.4375 - f1_score: 0.2191 - iou: 0.1586 - loss: 1.8460 - precision: 0.4375 - recall: 0.4375 - sensitivity: 0.2191 - specificity: 0.2191 - tversky: 0.2486 - val_AUC: 0.3912 - val_accuracy: 0.4259 - val_f1_score: 0.4226 - val_iou: 0.3023 - val_loss: 2.3190 - val_precision: 0.4259 - val_recall: 0.4259 - val_sensitivity: 0.4226 - val_specificity: 0.4226 - val_tversky: 0.4668 - learning_rate: 0.0010
# Epoch 13/50
# 2024-07-21 14:29:42.968968: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - AUC: 0.8383 - accuracy: 0.7627 - f1_score: 0.7627 - iou: 0.6054 - loss: 0.7373 - precision: 0.7627 - recall: 0.7627 - sensitivity: 0.7627 - specificity: 0.7627 - tversky: 0.7556
# 2024-07-21 14:34:56.230888: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 314s 466ms/step - AUC: 0.8384 - accuracy: 0.7627 - f1_score: 0.7627 - iou: 0.6054 - loss: 0.7373 - precision: 0.7627 - recall: 0.7627 - sensitivity: 0.7627 - specificity: 0.7627 - tversky: 0.7556 - val_AUC: 0.6340 - val_accuracy: 0.5648 - val_f1_score: 0.5565 - val_iou: 0.4104 - val_loss: 1.1541 - val_precision: 0.5648 - val_recall: 0.5648 - val_sensitivity: 0.5565 - val_specificity: 0.5565 - val_tversky: 0.5914 - learning_rate: 0.0010
# Epoch 14/50
# 2024-07-21 14:34:56.951170: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 14:34:57.049586: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 4:55 439ms/step - AUC: 0.7305 - accuracy: 0.6875 - f1_score: 0.6875 - iou: 0.4681 - loss: 0.8627 - precision: 0.6875 - recall: 0.6875 - sensitivity: 0.6875 - specificity: 0.6875 - tversky: 0.6483
# 2024-07-21 14:34:57.490574: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.7305 - accuracy: 0.6875 - f1_score: 0.3443 - iou: 0.2344 - loss: 0.8627 - precision: 0.6875 - recall: 0.6875 - sensitivity: 0.3443 - specificity: 0.3443 - tversky: 0.3246 - val_AUC: 0.6501 - val_accuracy: 0.6019 - val_f1_score: 0.5952 - val_iou: 0.4306 - val_loss: 1.0770 - val_precision: 0.6019 - val_recall: 0.6019 - val_sensitivity: 0.5952 - val_specificity: 0.5952 - val_tversky: 0.6117 - learning_rate: 0.0010
# Epoch 15/50
# 2024-07-21 14:34:58.237093: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - AUC: 0.8804 - accuracy: 0.7966 - f1_score: 0.7966 - iou: 0.6192 - loss: 0.4711 - precision: 0.7966 - recall: 0.7966 - sensitivity: 0.7966 - specificity: 0.7966 - tversky: 0.7681
# 2024-07-21 14:40:14.931879: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 317s 471ms/step - AUC: 0.8804 - accuracy: 0.7966 - f1_score: 0.7967 - iou: 0.6192 - loss: 0.4711 - precision: 0.7966 - recall: 0.7966 - sensitivity: 0.7967 - specificity: 0.7967 - tversky: 0.7681 - val_AUC: 0.9023 - val_accuracy: 0.8519 - val_f1_score: 0.8542 - val_iou: 0.6448 - val_loss: 0.4162 - val_precision: 0.8519 - val_recall: 0.8519 - val_sensitivity: 0.8542 - val_specificity: 0.8542 - val_tversky: 0.7853 - learning_rate: 2.0000e-04
# Epoch 16/50
# 2024-07-21 14:40:15.654912: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 14:40:15.797222: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 5:03 452ms/step - AUC: 0.8047 - accuracy: 0.7500 - f1_score: 0.7500 - iou: 0.5732 - loss: 0.7546 - precision: 0.7500 - recall: 0.7500 - sensitivity: 0.7500 - specificity: 0.7500 - tversky: 0.7367
# 2024-07-21 14:40:16.250895: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.8047 - accuracy: 0.7500 - f1_score: 0.3756 - iou: 0.2870 - loss: 0.7546 - precision: 0.7500 - recall: 0.7500 - sensitivity: 0.3756 - specificity: 0.3756 - tversky: 0.3689 - val_AUC: 0.9274 - val_accuracy: 0.8519 - val_f1_score: 0.8512 - val_iou: 0.6566 - val_loss: 0.3435 - val_precision: 0.8519 - val_recall: 0.8519 - val_sensitivity: 0.8512 - val_specificity: 0.8512 - val_tversky: 0.7960 - learning_rate: 2.0000e-04
# Epoch 17/50
# 2024-07-21 14:40:16.982343: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - AUC: 0.8803 - accuracy: 0.7947 - f1_score: 0.7946 - iou: 0.6147 - loss: 0.4669 - precision: 0.7947 - recall: 0.7947 - sensitivity: 0.7946 - specificity: 0.7946 - tversky: 0.7647
# 2024-07-21 14:45:23.756135: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 307s 456ms/step - AUC: 0.8803 - accuracy: 0.7947 - f1_score: 0.7946 - iou: 0.6147 - loss: 0.4669 - precision: 0.7947 - recall: 0.7947 - sensitivity: 0.7946 - specificity: 0.7946 - tversky: 0.7647 - val_AUC: 0.6823 - val_accuracy: 0.5648 - val_f1_score: 0.5655 - val_iou: 0.4457 - val_loss: 0.8408 - val_precision: 0.5648 - val_recall: 0.5648 - val_sensitivity: 0.5655 - val_specificity: 0.5655 - val_tversky: 0.6244 - learning_rate: 2.0000e-04
# Epoch 18/50
# 2024-07-21 14:45:24.459245: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 14:45:24.559133: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 4:57 443ms/step - AUC: 0.8203 - accuracy: 0.6875 - f1_score: 0.6875 - iou: 0.5350 - loss: 0.5653 - precision: 0.6875 - recall: 0.6875 - sensitivity: 0.6875 - specificity: 0.6875 - tversky: 0.7059
# 2024-07-21 14:45:25.003994: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.8203 - accuracy: 0.6875 - f1_score: 0.3443 - iou: 0.2679 - loss: 0.5653 - precision: 0.6875 - recall: 0.6875 - sensitivity: 0.3443 - specificity: 0.3443 - tversky: 0.3535 - val_AUC: 0.7164 - val_accuracy: 0.6389 - val_f1_score: 0.6458 - val_iou: 0.4696 - val_loss: 0.7897 - val_precision: 0.6389 - val_recall: 0.6389 - val_sensitivity: 0.6458 - val_specificity: 0.6458 - val_tversky: 0.6468 - learning_rate: 2.0000e-04
# Epoch 19/50
# 2024-07-21 14:45:25.738381: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - AUC: 0.8944 - accuracy: 0.8143 - f1_score: 0.8143 - iou: 0.6299 - loss: 0.4306 - precision: 0.8143 - recall: 0.8143 - sensitivity: 0.8143 - specificity: 0.8143 - tversky: 0.7766
# 2024-07-21 14:50:41.003522: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 316s 469ms/step - AUC: 0.8944 - accuracy: 0.8143 - f1_score: 0.8143 - iou: 0.6299 - loss: 0.4306 - precision: 0.8143 - recall: 0.8143 - sensitivity: 0.8143 - specificity: 0.8143 - tversky: 0.7766 - val_AUC: 0.7991 - val_accuracy: 0.7037 - val_f1_score: 0.7024 - val_iou: 0.5595 - val_loss: 0.7905 - val_precision: 0.7037 - val_recall: 0.7037 - val_sensitivity: 0.7024 - val_specificity: 0.7024 - val_tversky: 0.7220 - learning_rate: 2.0000e-04
# Epoch 20/50
# 2024-07-21 14:50:41.758576: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 14:50:41.866044: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 5:18 473ms/step - AUC: 0.8750 - accuracy: 0.7500 - f1_score: 0.7500 - iou: 0.6088 - loss: 0.4757 - precision: 0.7500 - recall: 0.7500 - sensitivity: 0.7500 - specificity: 0.7500 - tversky: 0.7640
# 2024-07-21 14:50:42.342553: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.8750 - accuracy: 0.7500 - f1_score: 0.3756 - iou: 0.3048 - loss: 0.4757 - precision: 0.7500 - recall: 0.7500 - sensitivity: 0.3756 - specificity: 0.3756 - tversky: 0.3826 - val_AUC: 0.7552 - val_accuracy: 0.6296 - val_f1_score: 0.6369 - val_iou: 0.5094 - val_loss: 1.0402 - val_precision: 0.6296 - val_recall: 0.6296 - val_sensitivity: 0.6369 - val_specificity: 0.6369 - val_tversky: 0.6794 - learning_rate: 2.0000e-04
# Epoch 21/50
# 2024-07-21 14:50:43.131450: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - AUC: 0.8859 - accuracy: 0.8032 - f1_score: 0.8034 - iou: 0.6230 - loss: 0.4543 - precision: 0.8032 - recall: 0.8032 - sensitivity: 0.8034 - specificity: 0.8034 - tversky: 0.7708
# ...
# Epoch 40/50
# 2024-07-21 15:42:30.603172: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 15:42:30.703863: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 5:18 475ms/step - AUC: 0.9961 - accuracy: 0.9375 - f1_score: 0.9375 - iou: 0.8152 - loss: 0.1309 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9375 - tversky: 0.9012
# 2024-07-21 15:42:31.181369: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.9961 - accuracy: 0.9375 - f1_score: 0.4694 - iou: 0.4082 - loss: 0.1309 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.4694 - specificity: 0.4694 - tversky: 0.4513 - val_AUC: 0.9490 - val_accuracy: 0.8611 - val_f1_score: 0.8571 - val_iou: 0.6576 - val_loss: 0.2988 - val_precision: 0.8611 - val_recall: 0.8611 - val_sensitivity: 0.8571 - val_specificity: 0.8571 - val_tversky: 0.7977 - learning_rate: 8.0000e-06
# Epoch 41/50
# 2024-07-21 15:42:32.065753: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - AUC: 0.9206 - accuracy: 0.8358 - f1_score: 0.8352 - iou: 0.6460 - loss: 0.3594 - precision: 0.8358 - recall: 0.8358 - sensitivity: 0.8352 - specificity: 0.8352 - tversky: 0.7890
# 2024-07-21 15:47:39.166451: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 308s 457ms/step - AUC: 0.9206 - accuracy: 0.8358 - f1_score: 0.8353 - iou: 0.6460 - loss: 0.3594 - precision: 0.8358 - recall: 0.8358 - sensitivity: 0.8353 - specificity: 0.8353 - tversky: 0.7890 - val_AUC: 0.9492 - val_accuracy: 0.8704 - val_f1_score: 0.8690 - val_iou: 0.6659 - val_loss: 0.2996 - val_precision: 0.8704 - val_recall: 0.8704 - val_sensitivity: 0.8690 - val_specificity: 0.8690 - val_tversky: 0.8028 - learning_rate: 8.0000e-06
# Epoch 42/50
# 2024-07-21 15:47:39.885669: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 15:47:39.984400: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 5:03 452ms/step - AUC: 0.8008 - accuracy: 0.6250 - f1_score: 0.6250 - iou: 0.5438 - loss: 0.6902 - precision: 0.6250 - recall: 0.6250 - sensitivity: 0.6250 - specificity: 0.6250 - tversky: 0.7132
# 2024-07-21 15:47:40.437933: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.8008 - accuracy: 0.6250 - f1_score: 0.3130 - iou: 0.2723 - loss: 0.6902 - precision: 0.6250 - recall: 0.6250 - sensitivity: 0.3130 - specificity: 0.3130 - tversky: 0.3571 - val_AUC: 0.9486 - val_accuracy: 0.8611 - val_f1_score: 0.8631 - val_iou: 0.6535 - val_loss: 0.3027 - val_precision: 0.8611 - val_recall: 0.8611 - val_sensitivity: 0.8631 - val_specificity: 0.8631 - val_tversky: 0.7964 - learning_rate: 8.0000e-06
# Epoch 43/50
# 2024-07-21 15:47:41.197820: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - AUC: 0.9248 - accuracy: 0.8410 - f1_score: 0.8410 - iou: 0.6486 - loss: 0.3486 - precision: 0.8410 - recall: 0.8410 - sensitivity: 0.8410 - specificity: 0.8410 - tversky: 0.7908
# 2024-07-21 15:52:47.040357: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 307s 455ms/step - AUC: 0.9247 - accuracy: 0.8409 - f1_score: 0.8409 - iou: 0.6486 - loss: 0.3486 - precision: 0.8409 - recall: 0.8409 - sensitivity: 0.8409 - specificity: 0.8409 - tversky: 0.7908 - val_AUC: 0.9545 - val_accuracy: 0.8704 - val_f1_score: 0.8661 - val_iou: 0.6696 - val_loss: 0.2831 - val_precision: 0.8704 - val_recall: 0.8704 - val_sensitivity: 0.8661 - val_specificity: 0.8661 - val_tversky: 0.8068 - learning_rate: 1.6000e-06
# Epoch 44/50
# 2024-07-21 15:52:47.761771: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 15:52:47.863364: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 5:02 451ms/step - AUC: 0.9531 - accuracy: 0.8750 - f1_score: 0.8750 - iou: 0.6703 - loss: 0.2914 - precision: 0.8750 - recall: 0.8750 - sensitivity: 0.8750 - specificity: 0.8750 - tversky: 0.8084
# 2024-07-21 15:52:48.316222: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.9531 - accuracy: 0.8750 - f1_score: 0.4382 - iou: 0.3356 - loss: 0.2914 - precision: 0.8750 - recall: 0.8750 - sensitivity: 0.4382 - specificity: 0.4382 - tversky: 0.4048 - val_AUC: 0.9489 - val_accuracy: 0.8889 - val_f1_score: 0.8929 - val_iou: 0.6624 - val_loss: 0.3016 - val_precision: 0.8889 - val_recall: 0.8889 - val_sensitivity: 0.8929 - val_specificity: 0.8929 - val_tversky: 0.8013 - learning_rate: 1.6000e-06
# Epoch 45/50
# 2024-07-21 15:52:49.064658: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - AUC: 0.9239 - accuracy: 0.8329 - f1_score: 0.8324 - iou: 0.6491 - loss: 0.3493 - precision: 0.8329 - recall: 0.8329 - sensitivity: 0.8324 - specificity: 0.8324 - tversky: 0.7910
# 2024-07-21 15:58:02.517884: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 314s 466ms/step - AUC: 0.9239 - accuracy: 0.8329 - f1_score: 0.8324 - iou: 0.6491 - loss: 0.3494 - precision: 0.8329 - recall: 0.8329 - sensitivity: 0.8324 - specificity: 0.8324 - tversky: 0.7910 - val_AUC: 0.9747 - val_accuracy: 0.9259 - val_f1_score: 0.9286 - val_iou: 0.6980 - val_loss: 0.2473 - val_precision: 0.9259 - val_recall: 0.9259 - val_sensitivity: 0.9286 - val_specificity: 0.9286 - val_tversky: 0.8257 - learning_rate: 1.6000e-06
# Epoch 46/50
# 2024-07-21 15:58:03.266949: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 15:58:03.379044: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 5:39 505ms/step - AUC: 0.9648 - accuracy: 0.8125 - f1_score: 0.8125 - iou: 0.6908 - loss: 0.2527 - precision: 0.8125 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.8125 - tversky: 0.8225
# 2024-07-21 15:58:03.887109: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.9648 - accuracy: 0.8125 - f1_score: 0.4069 - iou: 0.3459 - loss: 0.2527 - precision: 0.8125 - recall: 0.8125 - sensitivity: 0.4069 - specificity: 0.4069 - tversky: 0.4119 - val_AUC: 0.9529 - val_accuracy: 0.8796 - val_f1_score: 0.8750 - val_iou: 0.6791 - val_loss: 0.2818 - val_precision: 0.8796 - val_recall: 0.8796 - val_sensitivity: 0.8750 - val_specificity: 0.8750 - val_tversky: 0.8122 - learning_rate: 1.6000e-06
# Epoch 47/50
# 2024-07-21 15:58:04.647752: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - AUC: 0.9217 - accuracy: 0.8400 - f1_score: 0.8400 - iou: 0.6474 - loss: 0.3556 - precision: 0.8400 - recall: 0.8400 - sensitivity: 0.8400 - specificity: 0.8400 - tversky: 0.7896
# 2024-07-21 16:03:16.639372: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 313s 464ms/step - AUC: 0.9217 - accuracy: 0.8400 - f1_score: 0.8399 - iou: 0.6473 - loss: 0.3556 - precision: 0.8400 - recall: 0.8400 - sensitivity: 0.8399 - specificity: 0.8399 - tversky: 0.7896 - val_AUC: 0.9729 - val_accuracy: 0.9167 - val_f1_score: 0.9196 - val_iou: 0.7000 - val_loss: 0.2450 - val_precision: 0.9167 - val_recall: 0.9167 - val_sensitivity: 0.9196 - val_specificity: 0.9196 - val_tversky: 0.8278 - learning_rate: 1.6000e-06
# Epoch 48/50
# 2024-07-21 16:03:17.359510: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 16:03:17.461123: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 5:12 466ms/step - AUC: 0.9766 - accuracy: 0.8750 - f1_score: 0.8750 - iou: 0.6632 - loss: 0.2704 - precision: 0.8750 - recall: 0.8750 - sensitivity: 0.8750 - specificity: 0.8750 - tversky: 0.8034
# 2024-07-21 16:03:17.928604: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.9766 - accuracy: 0.8750 - f1_score: 0.4382 - iou: 0.3321 - loss: 0.2704 - precision: 0.8750 - recall: 0.8750 - sensitivity: 0.4382 - specificity: 0.4382 - tversky: 0.4023 - val_AUC: 0.9508 - val_accuracy: 0.8981 - val_f1_score: 0.8988 - val_iou: 0.6883 - val_loss: 0.2892 - val_precision: 0.8981 - val_recall: 0.8981 - val_sensitivity: 0.8988 - val_specificity: 0.8988 - val_tversky: 0.8200 - learning_rate: 3.2000e-07
# Epoch 49/50
# 2024-07-21 16:03:18.687878: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - AUC: 0.9212 - accuracy: 0.8441 - f1_score: 0.8441 - iou: 0.6460 - loss: 0.3580 - precision: 0.8441 - recall: 0.8441 - sensitivity: 0.8441 - specificity: 0.8441 - tversky: 0.7888
# 2024-07-21 16:08:26.588400: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 309s 458ms/step - AUC: 0.9212 - accuracy: 0.8441 - f1_score: 0.8442 - iou: 0.6460 - loss: 0.3580 - precision: 0.8441 - recall: 0.8441 - sensitivity: 0.8442 - specificity: 0.8442 - tversky: 0.7888 - val_AUC: 0.9715 - val_accuracy: 0.8981 - val_f1_score: 0.8988 - val_iou: 0.7036 - val_loss: 0.2450 - val_precision: 0.8981 - val_recall: 0.8981 - val_sensitivity: 0.8988 - val_specificity: 0.8988 - val_tversky: 0.8296 - learning_rate: 3.2000e-07
# Epoch 50/50
# 2024-07-21 16:08:27.303965: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 2024-07-21 16:08:27.404162: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
#   1/673 ━━━━━━━━━━━━━━━━━━━━ 5:10 461ms/step - AUC: 0.9648 - accuracy: 0.8125 - f1_score: 0.8125 - iou: 0.6148 - loss: 0.3172 - precision: 0.8125 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.8125 - tversky: 0.7685
# 2024-07-21 16:08:27.868507: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{function_node cond_false_75732}}{{node cond/IteratorGetNext}}]]
# 673/673 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - AUC: 0.9648 - accuracy: 0.8125 - f1_score: 0.4069 - iou: 0.3078 - loss: 0.3172 - precision: 0.8125 - recall: 0.8125 - sensitivity: 0.4069 - specificity: 0.4069 - tversky: 0.3848 - val_AUC: 0.9738 - val_accuracy: 0.9074 - val_f1_score: 0.9107 - val_iou: 0.6938 - val_loss: 0.2514 - val_precision: 0.9074 - val_recall: 0.9074 - val_sensitivity: 0.9107 - val_specificity: 0.9107 - val_tversky: 0.8239 - learning_rate: 3.2000e-07
# Restoring model weights from the end of the best epoch: 37.
# 2024-07-21 16:08:28.628091: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training time: 7713.82 seconds
# Saved model to disk
# Evaluate on test data
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 214ms/step - AUC: 0.9067 - accuracy: 0.8339 - f1_score: 0.8339 - iou: 0.6165 - loss: 0.3886 - precision: 0.8339 - recall: 0.8339 - sensitivity: 0.8339 - specificity: 0.8339 - tversky: 0.7647
# test loss test acc: [0.3701329529285431, 0.8331627249717712, 0.8331627249717712, 0.8331627249717712, 0.9149187803268433, 0.8330170512199402, 0.833017110824585, 0.833017110824585, 0.6287773251533508, 0.77396160364151]
# 2024-07-21 16:08:37.200988: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2024-07-21 16:08:44.443849: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node MultiDeviceIteratorGetNextFromShard}}]]
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 226ms/step
# Predicted and true label values saved
# Accuracy on test set :84.54452405322415%
# [[465 116]
#  [ 35 361]]

# %%
import pandas as pd

# Load the training history
df = pd.read_excel('output.xlsx')

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.figure(figsize=(10, 6))
plt.plot(df['accuracy'], label='Train Accuracy')
plt.plot(df['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.show()

# %%
# Plot loss
plt.figure(figsize=(10, 6))
plt.plot(df['loss'], label='Train Loss')
plt.plot(df['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()
plt.show()

# %%
# Plot precision
plt.figure(figsize=(10, 6))
plt.plot(df['precision'], label='Train Precision')
plt.plot(df['val_precision'], label='Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.title('Model Precision')
plt.legend()
plt.show()

# %%
# Plot recall
plt.figure(figsize=(10, 6))
plt.plot(df['recall'], label='Train Recall')
plt.plot(df['val_recall'], label='Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.title('Model Recall')
plt.legend()
plt.show()

# %%
# Plot AUC
plt.figure(figsize=(10, 6))
plt.plot(df['AUC'], label='Train AUC')
plt.plot(df['val_AUC'], label='Validation AUC')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.title('Model AUC')
plt.legend()
plt.show()

# %%
# Plot F1 Score
plt.figure(figsize=(10, 6))
plt.plot(df['f1_score'], label='Train F1 Score')
plt.plot(df['val_f1_score'], label='Validation F1 Score')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('Model F1 Score')
plt.legend()
plt.show()

# %%
# Plot sensitivity
plt.figure(figsize=(10, 6))
plt.plot(df['sensitivity'], label='Train Sensitivity')
plt.plot(df['val_sensitivity'], label='Validation Sensitivity')
plt.xlabel('Epochs')
plt.ylabel('Sensitivity')
plt.title('Model Sensitivity')
plt.legend()
plt.show()

# %%
# Plot specificity
plt.figure(figsize=(10, 6))
plt.plot(df['specificity'], label='Train Specificity')
plt.plot(df['val_specificity'], label='Validation Specificity')
plt.xlabel('Epochs')
plt.ylabel('Specificity')
plt.title('Model Specificity')
plt.legend()
plt.show()

# %%
# Plot IoU
plt.figure(figsize=(10, 6))
plt.plot(df['iou'], label='Train IoU')
plt.plot(df['val_iou'], label='Validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.title('Model IoU')
plt.legend()
plt.show()

# %%
# Plot Tversky
plt.figure(figsize=(10, 6))
plt.plot(df['tversky'], label='Train Tversky')
plt.plot(df['val_tversky'], label='Validation Tversky')
plt.xlabel('Epochs')
plt.ylabel('Tversky')
plt.title('Model Tversky')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load the true and predicted labels
truey = np.load('truey.npy')
predy = np.load('predy.npy')

# Compute the confusion matrix
cm = confusion_matrix(truey, predy)
labels = ['benign', 'malignant']

# Plot the confusion matrix
plt.figure(figsize=(10, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculated accuracies
accuracy_benign = 93  # Accuracy for benign images
accuracy_malignant = 75.7  # Accuracy for malignant images

# Data for plotting
categories = ['Benign', 'Malignant']
accuracies = [accuracy_benign, accuracy_malignant]
colors = ['green', 'orange']

# Create the bar plot
plt.figure(figsize=(8, 6))
plt.bar(categories, accuracies, color=colors)

# Add title and labels
plt.title('Percentage of correctly classified images')
plt.xlabel('Class')
plt.ylabel('Percentage')

# Display the plot
plt.show()
